# %%
from ImageCollection import plt
import numpy as np
import random
from ImageCollection import ImageCollection
# %matplotlib notebook

# %%
IC =ImageCollection()
get_n_rand = lambda sett=ImageCollection.coast_id,n=1 :random.sample(sett, n)

# %% [markdown]
# # Variables

# %%
#0 : mean bin
#1 : predominant bin
#2 : square sum
watch_var=IC.watch_var[1]
n_bins=256
mode='Lab'    #RGB,HSV,Lab
print(watch_var)
# Out:
# predominant bin

# %% [markdown]
# # histogrammes

# %%
idx=get_n_rand(n=2) +get_n_rand(ImageCollection.forest_id,n=2) +get_n_rand(ImageCollection.street_id,n=2)
IC.images_display(idx)
IC.view_histogrammes(idx)
IC.view_HSV_histogram(idx,12)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Hypothèses : Il y a des plages avec des couchers de soleil. Les forets d'hiver et d'automne peuvent potentiellement créés des nuages de points distincts (classes non compactes). Ligne horizontale dans la plage, dans une ville il y  a plein de rectangles.

# %% [markdown]
# # RGB

# %%
IC.getDatasetScatterGraph(mode,n_bins=n_bins,watch = watch_var)
# Out:
# <img src="data:image/png;base64,..." width="959">
# <img src="data:image/png;base64,..." width="1000">

# %%
IC.getDatasetTable(current_mode=mode,n_bins=n_bins,watch = watch_var)
# Out:
# <img src="data:image/png;base64,..." width="1000">
