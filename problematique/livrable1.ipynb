# %%
from ImageCollection import plt
import numpy as np
import random
from ImageCollection import ImageCollection

# %%
IC =ImageCollection()
get_n_rand = lambda sett=ImageCollection.coast_id,n=1 :random.sample(sett, n)

# %% [markdown]
# # RGB

# %%
idx=get_n_rand(n=5)
IC.images_display(idx)
IC.view_histogrammes(idx)

# %% [markdown]
# smth

# %%
IC.getDatasetScatterGraph('RGB',n_bins=256,watch = IC.watch_var[0])

# %%
IC.getDatasetTable(current_mode='RGB',n_bins=256,watch = IC.watch_var[0])
