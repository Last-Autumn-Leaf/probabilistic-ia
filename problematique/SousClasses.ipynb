# %%
from ImageCollection import plt
import numpy as np
import random
from ImageCollection import ImageCollection
from helpers.custom_class import *
# %matplotlib notebook

# %%
IC =ImageCollection()
get_n_rand = lambda sett=ImageCollection.coast_id,n=1 :random.sample(sett, n)

# %% [markdown]
# ## Choix des sous-classes

# %% [markdown]
# Idées:
# - Pour les coast: on peut diviser en classes jour et couchee de soleil grace a la teinte predominante dans le Hue. Les coast couchee de soleil ont une teinte(Hue) predominant sur les oranges/rouges contrairement aux autres.
#
# - Pour les forets: on peut diviser en classes vertes et hiver et automne grace a ??la teinte predominante dans le Hue. Observations: Les forets d'hiver ont une teinte(Hue) predominante en bleu contrairement aux autres.
#
# - Visualiser sur des echantillons de chaque classe pour voir si il y aurait des sous classes logiques

# %% [markdown]
# ## Visualisation sur les coasts

# %%
idx=get_n_rand(n=18)
IC.images_display(idx)
# IC.view_histogrammes(idx)
IC.view_HSV_histogram(idx,6)
# Out:
# <img src="data:image/png;base64,..." width="957">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # faire le tri

# %%
dimensions_list =[dimension(name = d_pred_bin,mode = HSV)]
tracker = VariablesTracker(dimensions_list)

tracker.update_dataset_size(len(IC.coast_id))
IC.getStat(IC.coast_id, tracker, n_bins=6)
# Out:
# most predominant bin,HSV,dissociative,avg,360

# %%
pred_bin = tracker.pick_var(dim=d_pred_bin, mode='HSV', index_mode=0) # On prend le H

# %%
coast_sunset = []
for id,bin in enumerate(pred_bin):
    if bin <2:
        coast_sunset.append(id)

# %%
rep=[0]*6
for bin in pred_bin:
    rep[int(bin)]+=1
rep
# Out:
# [66, 34, 7, 239, 7, 7]

# %%
type()
# Out:
# [2,
#  7,
#  10,
#  11,
#  13,
#  14,
#  15,
#  16,
#  18,
#  20,
#  24,
#  25,
#  28,
#  29,
#  35,
#  36,
#  41,
#  44,
#  48,
#  53,
#  60,
#  62,
#  63,
#  65,
#  76,
#  80,
#  82,
#  87,
#  89,
#  90,
#  91,
#  101,
#  102,
#  103,
#  110,
#  111,
#  119,
#  120,
#  127,
#  128,
#  132,
#  140,
#  141,
#  142,
#  146,
#  151,
#  153,
#  155,
#  157,
#  158,
#  167,
#  173,
#  174,
#  175,
#  177,
#  180,
#  181,
#  184,
#  191,
#  193,
#  194,
#  197,
#  198,
#  200,
#  203,
#  208,
#  209,
#  210,
#  212,
#  214,
#  216,
#  217,
#  220,
#  221,
#  223,
#  225,
#  226,
#  231,
#  239,
#  244,
#  251,
#  252,
#  253,
#  256,
#  263,
#  264,
#  265,
#  269,
#  273,
#  275,
#  277,
#  279,
#  280,
#  282,
#  283,
#  284,
#  292,
#  293,
#  295,
#  296,
#  300,
#  301,
#  304,
#  308,
#  312,
#  313,
#  314,
#  315,
#  316,
#  317,
#  322,
#  325,
#  326,
#  327,
#  328,
#  330,
#  331,
#  336,
#  340,
#  341,
#  343,
#  347,
#  348,
#  349,
#  351,
#  353,
#  355,
#  356,
#  357,
# ...

# %%
coast_sunset_id=IC.coast_id[coast_sunset]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [55], line 1
# ----> 1 coast_sunset_id=IC.coast_id[coast_sunset]
#
# TypeError: list indices must be integers or slices, not list

# %% [markdown]
# ## Visualisation sur les forest

# %%
# idx=get_n_rand(IC.forest_id,n=15)
# IC.images_display(idx)
# # IC.view_histogrammes(idx)
# IC.view_HSV_histogram(idx,12)

# %% [markdown]
# ## Visualisation sur les streets

# %%
# idx=get_n_rand(IC.street_id,n=10)
# IC.images_display(idx)
# # IC.view_histogrammes(idx)
# IC.view_HSV_histogram(idx,12)
